# %% [markdown]
# <a href="https://colab.research.google.com/github/metahead00/YOLOv8/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Sep  4 07:23:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.yaml'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 104.2ms
# Speed: 3.4ms preprocess, 104.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2

# %%
# !pwd
# Out:
# /content

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qLlKYidCUCBlxyzvQNjh")
project = rf.workspace("melike-beparmak").project("uav-detection-cvsav")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to UAV-Detection-1 in yolov8:: 100%|██████████| 958/958 [00:00<00:00, 2017.78it/s]

# %%
# !pip install ultralytics==8.0.134

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qLlKYidCUCBlxyzvQNjh")
project = rf.workspace("melike-beparmak").project("uav-detection-cvsav")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to UAV-Detection-1 in yolov8:: 100%|██████████| 958/958 [00:00<00:00, 1846.73it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=TRUE
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 148MB/s]
# New https://pypi.org/project/ultralytics/8.0.170 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/UAV-Detection-1
# Out:
# /content/UAV-Detection-1

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=TRUE
# Out:
# New https://pypi.org/project/ultralytics/8.0.170 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid
# README.dataset.txt  runs		 train	yolov8s.pt

# %%
# %cd /content/UAV-Detection-1/valid
# Out:
# /content/UAV-Detection-1/valid

# %%
# %cd images
# Out:
# /content/UAV-Detection-1/valid/images

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=TRUE
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 139MB/s]
# New https://pypi.org/project/ultralytics/8.0.170 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/UAV-Detection-1
# Out:
# /content/UAV-Detection-1

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=TRUE
# Out:
# New https://pypi.org/project/ultralytics/8.0.170 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=TRUE save=True
# Out:
# New https://pypi.org/project/ultralytics/8.0.170 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=TRUE
# Out:
# WARNING ⚠️ 'source' is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 224x192 4 persons, 1 truck, 95.7ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 128x224 2 persons, 1 tie, 63.6ms
# Speed: 0.9ms preprocess, 79.6ms inference, 1.9ms postprocess per image at shape (1, 3, 128, 224)
# Results saved to runs/detect/predict

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid	    yolov8s.pt
# README.dataset.txt  runs		 train	yolov8n.pt

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source="/content/UAV-Detection-1/test/images"
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/20 /content/UAV-Detection-1/test/images/a-114-_jpg.rf.d0b72e48eaade64d37b476f760e82105.jpg: 640x640 2 persons, 1 airplane, 16.5ms
# image 2/20 /content/UAV-Detection-1/test/images/a-117-_jpg.rf.81ac9d0839052014724673032474e07c.jpg: 640x640 1 person, 2 airplanes, 16.5ms
# image 3/20 /content/UAV-Detection-1/test/images/a-158-_jpg.rf.ec691b8284cf6dc689306cf445bdfd2c.jpg: 640x640 1 airplane, 16.5ms
# image 4/20 /content/UAV-Detection-1/test/images/a-164-_jpg.rf.dc02d73b49a7aebf22ecd2fc1c31ca26.jpg: 640x640 1 airplane, 16.6ms
# image 5/20 /content/UAV-Detection-1/test/images/a-172-_jpg.rf.8c0fac343c08d4cc8b9ed5a36d9faee7.jpg: 640x640 (no detections), 16.5ms
# image 6/20 /content/UAV-Detection-1/test/images/a-174-_jpg.rf.32bdbfe336071f3f1a75c12298f354d4.jpg: 640x640 (no detections), 16.5ms
# ...

# %%
# !yolo task=detect mode=predict model="/content/UAV-Detection-1/runs/detect/train4/weights/best.pt" source="/content/UAV-Detection-1/test/images"
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/20 /content/UAV-Detection-1/test/images/a-114-_jpg.rf.d0b72e48eaade64d37b476f760e82105.jpg: 224x224 5 UAVs, 6.8ms
# image 2/20 /content/UAV-Detection-1/test/images/a-117-_jpg.rf.81ac9d0839052014724673032474e07c.jpg: 224x224 1 UAV, 8.1ms
# image 3/20 /content/UAV-Detection-1/test/images/a-158-_jpg.rf.ec691b8284cf6dc689306cf445bdfd2c.jpg: 224x224 1 UAV, 8.1ms
# image 4/20 /content/UAV-Detection-1/test/images/a-164-_jpg.rf.dc02d73b49a7aebf22ecd2fc1c31ca26.jpg: 224x224 4 UAVs, 8.4ms
# image 5/20 /content/UAV-Detection-1/test/images/a-172-_jpg.rf.8c0fac343c08d4cc8b9ed5a36d9faee7.jpg: 224x224 1 UAV, 7.0ms
# image 6/20 /content/UAV-Detection-1/test/images/a-174-_jpg.rf.32bdbfe336071f3f1a75c12298f354d4.jpg: 224x224 2 UAVs, 6.8ms
# ...

# %%
# !yolo task=detect mode=predict model="/content/UAV-Detection-1/runs/detect/train4/weights/best.pt" source="/content/UAV-Detection-1/test/"
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 93.5ms
# video 1/1 (2/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 9.0ms
# video 1/1 (3/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 9.0ms
# video 1/1 (4/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 9.1ms
# video 1/1 (5/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 9.3ms
# video 1/1 (6/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 8.8ms
# video 1/1 (7/3724) /content/UAV-Detection-1/test/PD-1 fixed-wing UAV by Ukrspecsystems.mp4: 128x224 1 UAV, 9.1ms
# ...
